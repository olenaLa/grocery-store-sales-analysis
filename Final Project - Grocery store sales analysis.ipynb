# %% [markdown]
# # Вітаю на фінальному проєкті!
# Протягом курсу ми навчились завантажувати дані в Python, трансформувати їх, чистити, агрегувати, знаходити з допомогою даних відповіді на наші питання.
# Задача фінального проєкту - продемонструвати той рівень роботи з даними, на якому ви є зараз.
#
# Цей ноутбук буде присвячений аналізу даних з файла `Grocery DataBase.xlsx`, який є в папці `Дані` на Диску. Так, це Excel файл, але ми можемо дуже просто завантажувати дані з нього у Python. Покажу пару команд для роботи з Excel файлом.

# %% [markdown]
# Для початку встановимо бібліотеку, яка потрібна для роботи з Excel файлами з pandas. Можна встановити тут, або в терміналі, але якщо Ви встановлюєте в терміналі, то після того треба перезапустити ядро (Kernel) ноутбуку, аби бібліотека точно підтягнулась. Іноді підтягується і без того, але це на випадок, що робити, якщо компілятор каже, що її не бачить.

# %%
# !pip install openpyxl

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Ось так можемо переглянути, які є листки в Excel файлі:

# %%
# замініть на шлях до файлу на своєму комп`ютері
path_to_file = '../data/grocery/Grocery Database.xlsx'

# %%
xl = pd.ExcelFile(path_to_file)
xl.sheet_names
# Out:
# ['Grosto DB', 'Sheet2', 'Fact Summary']

# %% [markdown]
# А так можемо зчитати конкретний листок:

# %%
xl.parse('Fact Summary')
# Out:
#     S.No.          Column Name  \
# 0       1       Receipt Number
# 1       2                 Date
# 2       3                 Year
# 3       4                Month
# 4       5                 Time
# 5       6        Mobile Number
# 6       7        Membership ID
# 7       8  Loyalty Card Points
# 8       9                  Age
# 9      10               Gender
# 10     11                 City
# 11     12              Country
# 12     13             Category
# 13     14         Sub_Category
# 14     15                Items
# 15     16               Brand
# 16     17         Description
# 17     18                Price
# 18     19                  QTY
# 19     20                 DISC
# 20     21      Net Bill Amount
# 21     22                  GST
# 22     23    Gross Bill Amount
# 23     24         Payment Mode
# 24     25            Bank Name
# 25     26      % Profit Margin
# 26     27     % Operating Cost
# 27     28       % Product Cost
# 28     29        Profit Margin
# ...

# %% [markdown]
# Читати дані можна і з Pandas, але тут немає можливості переглянути наявні листки, а також довше відбувається читання даних.

# %%
df = pd.read_excel(path_to_file)

# %% [markdown]
# В файлі ви знайдете самі дані та опис колонок.
#
# **Задача**: Уявіть, що Вам дали цей набір даних з питанням "Що корисного ми можемо з них взяти для розвитку нашого бізнесу?". То Вам необхідно розказати бізнесу історію про ці дані у форматі
# 1. питання, яке Вас як робітника цього бізнесу, який дуже вболіває за його успіх, цікавить щодо цих даних
# 2. код для відповіді на це питання
# 3. висновки, які я можу зробити з огляду на результат виконання коду: які рішення ми можемо прийняти щодо подальших кроків в аналізі або які рекомендації Ви б дали бізнесу виходячи з результатів.
#
# **Необхідно** поставити до даних _мінімум_ 10 бізнес-питань, при цьому зробивши
# - початковий аналіз даних: їх розмір, структура, наявність пропущених значень та що з ними зробити, зміна типів даних там, де це доречно зробити (наприклад, якщо колонка завантажилась як тип string, а з опису видно, що там має бути float) - ця частина не входить у бізнес-питання, але є необхідною при аналізі даних.
# - _мінімум_ 1 зведену таблицю або її аналог
# - _мінімум_ 5 візуалізацій, 3 з яких мають різний тип (наприклад, scatter plot, line plot, pair plot)
#
# В даному мінімум-наборі немає вимоги на використання SQL та тестування статистичних гіпотез. Але якщо Вам хочеться потренуватись, то Ви можете це зробити скориставшись pandasql, а також перевірити, чи є відмінність між двома групами у якомусь показнику з допомогою тестування статистичних гіпотез. Останнє найбільш доречно, якщо, наприклад, ми беремо чоловіків і жінок, бачимо що у них доволі схожі середні чеки, але наче відрізняються. Аби зрозуміти, чи різниця статистично значущою, можна це перевірити з допомогою тестування стат. гіпотез.
#
# Питанням може бути як "Яка є кількість унікальних чеків в цьому наборі даних?" так і щось значно складніше. Якщо у Вас складне питання, і аби відповісти на нього Ви мали відповісти на 3 менших питання (зробити якісь трансформації над даними, подивитись щось), то це рахується як 3 питання з 10 необхідних у завданні. Звісно ж Ви можете зробити більше за встановлений мінімум - все буде перевірено :)
#
# Тут є великий простір для Вашої фантазії. **Тому рекомендація:** виділіть на це завданні певну кількість годин (наприклад, середнє значення по тому, скільки у Вас займало виконання домашніх завдань в курсі, але я рекомендую не менше 2х годин роботи)
# і поставте собі за ціль всю роботу вмістити в цю кількість годин.
# Це дозволить Вам управляти своїм часом, пріоритизувати питання, які ставите до даних. І так часто є в роботі: коли ми не знаємо, що ми шукаємо, ми ставимо обмеження по часу (задача типу spike) і робимо все, що встигнемо, за цей час.
#
# По закінченню - завантажуємо ноутбук на git і додаємо посилання в здачу роботи в Eduflow.
# До речі, з часом, вам може захотітись доповнити цей ноутбук, коли арсенал ваших навичок по роботі з даними розшириться. І це буде чудова ідея!
#
# **Успіхів!**

# %% [markdown]
# Початковий аналіз

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50447 entries, 0 to 50446
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Receipt Number       50447 non-null  object
#  1   Date                 50447 non-null  datetime64[ns]
#  2   Year                 50447 non-null  int64
#  3   Month                50447 non-null  int64
#  4   Time                 50447 non-null  object
#  5   Mobile Number        50447 non-null  int64
#  6   Membership ID        50447 non-null  object
#  7   Loyalty Card Points  50447 non-null  int64
#  8   Age                  50447 non-null  int64
#  9   Gender               50447 non-null  object
#  10  City                 50447 non-null  object
#  11  Country              50447 non-null  object
#  12  Category             50447 non-null  object
#  13  Sub_Category         50447 non-null  object
#  14  Items                50447 non-null  object
# ...

# %%
with pd.option_context("display.precision", 2):
    display(df.describe())
# Out:
#            Year     Month  Mobile Number  Loyalty Card Points       Age  \
# count  50447.00  50447.00       5.04e+04             50447.00  50447.00
# mean    2017.67      6.48       9.89e+09                18.36     35.80
# std        1.11      3.45       7.64e+07                16.16     14.02
# min     2016.00      1.00       7.92e+09                 0.00     15.00
# 25%     2017.00      3.00       9.84e+09                 6.00     23.00
# 50%     2018.00      7.00       9.90e+09                14.00     35.00
# 75%     2019.00     10.00       9.95e+09                26.00     47.00
# max     2019.00     12.00       1.00e+10               116.00     75.00
#
#           Price       QTY      DISC    Amount  Net Bill Amount       GST  \
# count  50447.00  50447.00  50447.00  50447.00         50447.00  50447.00
# mean       7.42      1.55      0.03     11.17            66.70      0.09
# std        4.75      0.65      0.01      9.23            45.27      0.02
# ...

# %%
if df.isnull().values.any():
    print("Є порожні значення або значення NaN.")
else:
    print("Немає порожніх значень або значень NaN.")
# Out:
# Немає порожніх значень або значень NaN.

# %%
df.head()
# Out:
#   Receipt Number       Date  Year  Month             Time  Mobile Number  \
# 0       GIJ00001 2016-01-02  2016      1  10:08:03.260000     9793548581
# 1       GIJ00002 2016-01-02  2016      1  15:46:50.832000     9938441276
# 2       GIJ00003 2016-01-02  2016      1  11:28:52.166000     9976742552
# 3       GIJ00003 2016-01-02  2016      1  11:28:52.166000     9976742552
# 4       GIJ00003 2016-01-02  2016      1  11:28:52.166000     9976742552
#
#   Membership ID  Loyalty Card Points  Age  Gender  ...  GST Gross Bill Amount  \
# 0     MIDID0001                    1   36    Male  ...  0.1          13.32408
# 1     MIDID0002                    2   54    Male  ...  0.1          25.26480
# 2     MIDID0003                    1   16  Female  ...  0.1          42.18786
# 3     MIDID0003                    1   16  Female  ...  0.1          42.18786
# 4     MIDID0003                    2   16  Female  ...  0.1          42.18786
#
# ...

# %%
from datetime import datetime

# %%
df_grocery = df.copy()
fixed_date = datetime(2023, 1, 1)

df_grocery['Time'] = df_grocery['Time'].apply(lambda x: datetime.combine(fixed_date, x))

# %%
df_grocery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50447 entries, 0 to 50446
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Receipt Number       50447 non-null  object
#  1   Date                 50447 non-null  datetime64[ns]
#  2   Year                 50447 non-null  int64
#  3   Month                50447 non-null  int64
#  4   Time                 50447 non-null  datetime64[ns]
#  5   Mobile Number        50447 non-null  int64
#  6   Membership ID        50447 non-null  object
#  7   Loyalty Card Points  50447 non-null  int64
#  8   Age                  50447 non-null  int64
#  9   Gender               50447 non-null  object
#  10  City                 50447 non-null  object
#  11  Country              50447 non-null  object
#  12  Category             50447 non-null  object
#  13  Sub_Category         50447 non-null  object
#  14  Items                50447 non-null  object
# ...

# %%
df_grocery.head()
# Out:
#   Receipt Number       Date  Year  Month                    Time  \
# 0       GIJ00001 2016-01-02  2016      1 2023-01-01 10:08:03.260
# 1       GIJ00002 2016-01-02  2016      1 2023-01-01 15:46:50.832
# 2       GIJ00003 2016-01-02  2016      1 2023-01-01 11:28:52.166
# 3       GIJ00003 2016-01-02  2016      1 2023-01-01 11:28:52.166
# 4       GIJ00003 2016-01-02  2016      1 2023-01-01 11:28:52.166
#
#    Mobile Number Membership ID  Loyalty Card Points  Age  Gender  ...  GST  \
# 0     9793548581     MIDID0001                    1   36    Male  ...  0.1
# 1     9938441276     MIDID0002                    2   54    Male  ...  0.1
# 2     9976742552     MIDID0003                    1   16  Female  ...  0.1
# 3     9976742552     MIDID0003                    1   16  Female  ...  0.1
# 4     9976742552     MIDID0003                    2   16  Female  ...  0.1
#
#   Gross Bill Amount Payment Mode                 Bank Name % Profit Margin  \
# ...

# %% [markdown]
# 1. Який загальний дохід магазину за кожен рік?

# %%
yearly_revenue = df_grocery.groupby('Year')['Gross Bill Amount'].sum()
pd.options.display.float_format = '{:.0f}'.format
yearly_revenue_df = yearly_revenue.reset_index()
yearly_revenue_df.columns = ['Рік', 'Загальний валовий дохід']

print(yearly_revenue_df)
# Out:
#     Рік  Загальний валовий дохід
# 0  2016                   754649
# 1  2017                   811617
# 2  2018                   939679
# 3  2019                  1145354

# %% [markdown]
# **Висновок**: Дохід зростає з кожним роком, що говорить про успішну бізнес-модель.

# %% [markdown]
# 2. Як змінюється дохід магазину в різні місяці?

# %%
monthly_revenue = df_grocery.groupby('Month')['Gross Bill Amount'].sum()

plt.figure(figsize=(10, 6))
monthly_revenue.plot(kind='line', color='green', marker='o', linestyle='-')
plt.title("Store's revenue variation across months")
plt.xlabel("Month")
plt.ylabel("Total Revenue")
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# %% [markdown]
# **Висновок**: Виходячи зі спостереження, що грудень (12-й місяць) і січень (1-й місяць) мають вищі доходи, магазину слід розглянути можливість запуску спеціальних акцій і маркетингових кампаній протягом цих місяців, щоб отримати вигоду від збільшення витрат клієнтів під час святкового сезону та початку року, потенційно підвищуючи загальну прибутковість. Крім того, магазин повинен забезпечити наявність достатнього запасу товарів та персоналу для задоволення підвищеного попиту в цей період.

# %% [markdown]
# 3. Які найпопулярніші способи оплати обирають клієнти?

# %%
unique_payment_modes = df_grocery['Payment Mode'].unique()

print("Unique Payment Modes:", unique_payment_modes)
# Out:
# Unique Payment Modes: ['Card' 'Cash' 'Wallet']

# %%
payment_mode_counts = df_grocery['Payment Mode'].value_counts()

custom_colors = {
    'Card': 'goldenrod',
    'Cash': 'limegreen',
    'Wallet': 'turquoise'
}

plt.figure(figsize=(10, 6))
for payment_mode, color in custom_colors.items():
    subset = payment_mode_counts[payment_mode_counts.index == payment_mode]
    plt.bar(subset.index, subset.values, color=color, label=payment_mode)

plt.title("Most popular payment modes")
plt.xlabel("Payment mode")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %% [markdown]
# **Висновок**: На основі даних і бачення, що оплата готівкою ще поширена магазин може проводити рекламні акції, які заохочуватимуть клієнтів, які платять готівкою, спробувати цифрові методи оплати.

# %% [markdown]
# 4. Яка категорія товарів приносить найбільший дохід магазину?

# %%
category_revenue = df_grocery.groupby('Category')['Gross Bill Amount'].sum()

highest_revenue_category = category_revenue.idxmax()
total_highest_revenue = category_revenue.max()

print(f"Категорія з найбільшим доходом це'{highest_revenue_category}' з загальним доходом {total_highest_revenue:.2f}$.")
# Out:
# Категорія з найбільшим доходом це'Frozen' з загальним доходом 511380.73$.

# %% [markdown]
# 5. Чи є різниця в купівельній поведінці покупців чоловічої та жіночої статі?

# %%
male_customers = df_grocery[df_grocery['Gender'] == 'Male']
female_customers = df_grocery[df_grocery['Gender'] == 'Female']
selected_columns = ['Gross Bill Amount']
gender_describe = df_grocery.groupby('Gender')[selected_columns].describe()
print(gender_describe)

plt.figure(figsize=(10, 6))
plt.hist([male_customers['Gross Bill Amount'], female_customers['Gross Bill Amount']], bins=20, color=['blue', 'pink'], alpha=0.7, label=['Male', 'Female'])
plt.title("Purchase behavior by gender")
plt.xlabel("Gross Bill Amount")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
#        Gross Bill Amount
#                    count mean std min 25% 50% 75% max
# Gender
# Female             41822   73  50   1  39  64  99 559
# Male                8625   70  46   1  38  62  95 392

# %% [markdown]
# **Висновок**: необхідно розробляти цільові маркетингові кампанії та рекламні акції, які спеціально обслуговують уподобання жінок-клієнтів і їх купівельні звички.

# %% [markdown]
# 6. Який середній відсоток прибутку магазину?

# %%
average_profit_margin_percentage = (df_grocery['Profit Margin'] / df_grocery['Gross Bill Amount']).mean() * 100
print(f"Середній відсоток прибутку магазину складає: {average_profit_margin_percentage:.2f}%")
# Out:
# Середній відсоток прибутку магазину складає: 2.58%

# %% [markdown]
# **Висновок**: так як для продуктових магазинів загалом характерний невисокий середній відсоток прибутку(до 5%), то в цілому даний показник є непоганим.

# %% [markdown]
# 7. Дослідимо залежність між суми валого прибутку і операційними витратами:

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_grocery, x='Operating Cost', y='Gross Bill Amount', alpha=0.5)
sns.regplot(x='Operating Cost', y='Gross Bill Amount', data=df_grocery, line_kws={'color':'red', 'lw':'1'}, scatter_kws={'alpha': 0.1});
plt.title("Operating Cost vs. Gross Bill Amount")
plt.xlabel("Operating Cost")
plt.ylabel("Gross Bill Amount")
plt.grid(True)
plt.show()

# %% [markdown]
# **Висновок**: враховуючи концентрацію залежності у діапазоні 10дол. на осі операційних витрат і 250$ на осі суми валового рахунку, можливо, доцільно зосередитися на оптимізації та впорядкуванні операцій у цьому діапазоні. Магазину слід шукати способи скорочення операційних витрат, зберігаючи або збільшуючи суми валових рахунків у цій «ефективній» зоні. Також слід провести аналіз викидів, які можуть представляти унікальні проблеми, які потребують особливої уваги.

# %% [markdown]
# 8. Проведемо додатковий аналіз прибутковості шляхом окремого розрахунку маржі прибутку для операцій у зоні концентрації з попереднього аналізу та викидів

# %%
df_grocery['Profit Margin'] = (df_grocery['Gross Bill Amount'] - df_grocery['Product Cost'] - df_grocery['Operating Cost']) / df_grocery['Gross Bill Amount']

concentration_zone = (df_grocery['Operating Cost'] <= 10) & (df_grocery['Gross Bill Amount'] <= 250)

concentration_data = df_grocery[concentration_zone]
outliers_data = df_grocery[~concentration_zone]

average_profit_margin_concentration = concentration_data['Profit Margin'].mean()
average_profit_margin_outliers = outliers_data['Profit Margin'].mean()

print(f"Середня рентабельність у зоні концентрації: {average_profit_margin_concentration:.2%}")
print(f"Середня рентабельність для викидів: {average_profit_margin_outliers:.2%}")
# Out:
# Середня рентабельність у зоні концентрації: 77.72%
# Середня рентабельність для викидів: 82.28%

# %% [markdown]
# **Висновок**: Слід продовжувати зосереджуватися на оптимізації операцій і прибутковості в зоні концентрації, оскільки вона, становить значну частину бізнесу магазину.

# %% [markdown]
# 9. Як змінюються операційні витрати магазину у відсотках від доходу з роками?

# %%
yearly_data = df_grocery.groupby('Year').agg({'Operating Cost': 'sum', 'Product Cost': 'sum', 'Gross Bill Amount': 'sum'})
yearly_data['Operating Cost Percentage'] = (yearly_data['Operating Cost'] / yearly_data['Gross Bill Amount']) * 100
yearly_data['Net Profit'] = yearly_data['Gross Bill Amount'] - (yearly_data['Operating Cost'] + yearly_data['Product Cost'])

print(yearly_data[['Net Profit', 'Operating Cost Percentage']])
# Out:
#       Net Profit  Operating Cost Percentage
# Year
# 2016      649050                          2
# 2017      693636                          2
# 2018      804489                          2
# 2019      983983                          2

# %% [markdown]
# **Висновок**: поєднання зростання чистого прибутку та стабільного відсотка операційних витрат свідчить про те, що магазин ефективно керував своїми витратами, збільшуючи дохід. Це позитивний знак для фінансового стану магазину.

# %% [markdown]
# 10. Побудуємо box-plot по розприділенню Суми чистого доходу по країнам:

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Country', y='Net Bill Amount', data=df_grocery)
plt.title('Net Bill Amount by Country')
plt.xlabel('Country')
plt.ylabel('Net Bill Amount')
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.show()

# %% [markdown]
# **Висновок**: Розподіл прибутку по країнам більш-менш однаковий. А те що правий вус - довший, свідчить про позитивний перекіс, що означає, що існують транзакції з високою вартістю.

# %% [markdown]
# 11. Подивимось на динаміку суми чистого доходу по годинам в країнах.

# %%
df_grocery['Hour'] = df_grocery['Time'].dt.hour
net_bill_amount_country_pivot = pd.pivot_table(
    df_grocery,
    values='Net Bill Amount',
    index='Hour',
    columns='Country',
    aggfunc='sum'
)
print(net_bill_amount_country_pivot)
# Out:
# Country  Indonesia  Malaysia  Philippines  Singapore
# Hour
# 10           54047     62285        57010      98761
# 11           53838     64823        55784      95912
# 12           60277     51298        63566     100155
# 13           56312     65464        69912     105730
# 14           50206     54706        57736     108256
# 15           56111     62931        68287     100839
# 16           43133     57284        63327     104861
# 17           50502     61785        65580      98687
# 18           44164     57947        75637     107118
# 19           47732     63953        69033      89582
# 20           46756     66881        80530     106537
# 21           53317     58403        73427     104152

# %%
color_palette = sns.color_palette('deep', len(net_bill_amount_country_pivot.columns))
plt.figure(figsize=(12, 6))
for i, country in enumerate(net_bill_amount_country_pivot.columns):
    plt.plot(net_bill_amount_country_pivot.index, net_bill_amount_country_pivot[country], marker='s', color=color_palette[i], label=country)

plt.title('Hourly Net Bill Amount by Country')
plt.xlabel('Hour')
plt.ylabel('Net Bill Amount')
plt.grid(True)
plt.legend()
plt.xticks(range(24))
plt.show()

# %% [markdown]
# **Висновок**: Можемо помітити коли продажі найвищі(в Філіпінах і Малазії ця тенденція явно припадає на кінец дня), і можемо виділити більше ресурсів або рекламних акцій у цей час, щоб максимізувати дохід.
# Розуміння відмінностей по країнам може сформувати маркетингові та операційні стратегії, адаптовані до кожної країни.
